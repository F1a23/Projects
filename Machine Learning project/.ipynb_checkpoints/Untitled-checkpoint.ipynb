# %%
# 1. استيراد المكتبات
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# 2. قراءة البيانات (CSV أو Excel)
df = pd.read_csv("data.csv")
df
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review Rating  \
# 0     The ambience was good, food was quite good . h...      5
# 1     Ambience is too good for a pleasant evening. S...      5
# 2     A must try.. great food great ambience. Thnx f...      5
# 3     Soumen das and Arun was a great guy. Only beca...      5
# 4     Food is good.we ordered Kodi drumsticks and ba...      5
# ...

# %%
# 3. فحص الأعمدة
print("أسماء الأعمدة:", df.columns.tolist())
print(df.info())
# Out:
# أسماء الأعمدة: ['Restaurant', 'Reviewer', 'Review', 'Rating', 'Metadata', 'Time', 'Pictures', '7514']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Restaurant  10000 non-null  object
#  1   Reviewer    9962 non-null   object
#  2   Review      9955 non-null   object
#  3   Rating      9962 non-null   object
#  4   Metadata    9962 non-null   object
#  5   Time        9962 non-null   object
#  6   Pictures    10000 non-null  int64
#  7   7514        1 non-null      float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 625.1+ KB
# None

# %%
# 4. تنظيف الأعمدة النصية (إزالة مسافات وتوحيد الحروف)
df.columns = df.columns.str.strip()
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].astype(str).str.strip().str.lower()

# %%
# 5. التعامل مع القيم المفقودة
for col in df.select_dtypes(include=['int64','float64']).columns:
    df[col] = df[col].fillna(df[col].median())

for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].fillna("unknown")

# %%
# 6. إزالة التكرارات
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (9964, 8)

# %%
# 7. معالجة القيم الشاذة (Outliers) لكل عمود رقمي
for col in df.select_dtypes(include=['int64','float64']).columns:
    z_scores = np.abs((df[col] - df[col].mean()) / df[col].std())
    df = df[z_scores < 4]

# %%
df.shape
# Out:
# (0, 8)

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns
print("الأعمدة الرقمية:", num_cols)
print("عدد الصفوف:", len(df))
# Out:
# الأعمدة الرقمية: Index(['Pictures', '7514'], dtype='object')
# عدد الصفوف: 0

# %%
# 8. ترميز الأعمدة النصية (Encoding)
for col in df.select_dtypes(include=['object']).columns:
    df.loc[:, col] = le.fit_transform(df[col])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # 8. ترميز الأعمدة النصية (Encoding)
#       2 for col in df.select_dtypes(include=['object']).columns:
# ----> 3     df.loc[:, col] = le.fit_transform(df[col])
#
# NameError: name 'le' is not defined

# %%
# 9. توحيد المقياس (Scaling) للأعمدة الرقمية
for col in df.select_dtypes(include=['int64','float64']).columns:
    z_scores = np.abs((df[col] - df[col].mean()) / df[col].std())
    df = df[z_scores < 4]

# %%
 # 10. حفظ البيانات النظيفة
df.to_csv("cleaned_data_v2.csv", index=False)
print("cleaned_data_v2.csv")

# %%
# عرض عدد القيم المفقودة في كل عمود
print(df.isnull().sum())

# %%
df
# Out:
# Empty DataFrame
# Columns: [Restaurant, Reviewer, Review, Rating, Metadata, Time, Pictures, 7514]
# Index: []
